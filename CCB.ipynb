# %%
pip show cellpose
# Out:
# Name: cellpose
# Version: 4.0.4
# Summary: anatomical segmentation algorithm
# Home-page: https://github.com/MouseLand/cellpose
# Author: Marius Pachitariu and Carsen Stringer
# Author-email: stringerc@janelia.hhmi.org
# License: BSD
# Location: c:\Users\jesse\anaconda3\envs\Microscopie\Lib\site-packages
# Requires: fastremap, fill-voids, imagecodecs, natsort, numpy, opencv-python-headless, roifile, scipy, segment_anything, tifffile, torch, torchvision, tqdm
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Cellpose
#
# #### Cell diameter
#
# You can use Fiji to measure the average cell diameter of the cells in the image with the following step-by-step plan:
#
# 1. Open Fiji.
# 2. Open the same image as in Cellpose.
# 3. Click on the *straight* line icon.
# 4. Drag your mouse from the one cell end to the other cell end.
# 5. Check the value behind the *length* variable (in the text below the straight line).
# 6. Keep track of this value and repeat this action by a few cells.
# 7. Calculate the average cell diameter.

# %% [markdown]
# ###### QUESTION <br><br>*Double click or press enter on this cell to answer the question. <br>CTRL+ENTER --or-- SHIFT+ENTER if you are done writing your answer.*
#
# What is the average diameter of the cell nucleus?
#
# - *Answer here*

# %% [markdown]
# Use the diameter from above in the Cellpose application

# %%
pip install cellpose

# %%
python -m cellpose --Zstack
